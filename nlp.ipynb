# %%
# !python -m pip install --upgrade pip --no-user

# %%
# !where python
# Out:
# d:\DEV\python-envs\ai-env\Scripts\python.exe
# D:\DEV\tools\Python\python.exe

# %% [markdown]
# # Week 1

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 2.4 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/12.8 MB 2.2 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.6/12.8 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.8 MB 2.2 MB/s eta 0:00:05
#      ------ --------------------------------- 2.1/12.8 MB 1.8 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 1.7 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.8 MB/s eta 0:00:06
#      --------- ------------------------------ 2.9/12.8 MB 1.7 MB/s eta 0:00:06
#      --------- ------------------------------ 3.1/12.8 MB 1.6 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 1.5 MB/s eta 0:00:07
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm") # Loads the English pipeline

# %% [markdown]
# # Week 2

# %%
#Week-2
doc = nlp("spaCy is a fast NLP library. It's used for tokenization!")
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop, token.is_alpha, token.idx)
# Out:
# spaCy spacy INTJ False True 0
# is be AUX True True 6
# a a DET True True 9
# fast fast ADJ False True 11
# NLP NLP PROPN False True 16
# library library NOUN False True 20
# . . PUNCT False False 27
# It it PRON True True 29
# 's be AUX True False 31
# used use VERB True True 34
# for for ADP True True 39
# tokenization tokenization NOUN False True 43
# ! ! PUNCT False False 55

# %% [markdown]
# # Week 3

# %%
#Week-3
# Load the English model
nlp_2 = spacy.load("en_core_web_sm")
# Input sentence
sentence = "The quick brown fox jumps over the lazy dog."
# Parse the sentence
doc = nlp_2(sentence)
# Print dependencies
for token in doc:
    print(f"{token.text:<12} -> {token.dep_:<10} (head: {token.head.text})")
# Out:
# The          -> det        (head: fox)
# quick        -> amod       (head: fox)
# brown        -> amod       (head: fox)
# fox          -> nsubj      (head: jumps)
# jumps        -> ROOT       (head: jumps)
# over         -> prep       (head: jumps)
# the          -> det        (head: dog)
# lazy         -> amod       (head: dog)
# dog          -> pobj       (head: over)
# .            -> punct      (head: jumps)

# %%
pip install --force-reinstall ipython
# Out:
# ...
#   Using cached ipython-9.11.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached wcwidth-0.6.0-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached parso-0.8.6-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# ...

# %%
exit()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from spacy import displacy
from IPython.display import HTML, display

# 1. Use jupyter=False to ensure it returns a string instead of trying to 
# render itself automatically inside the function call.
html = displacy.render(doc, style="dep", jupyter=False)

# 2. Wrap and display
display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="14af29f0effd4a58abb5818a03c8b382-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">brown</tspan>
# ...

# %%
pip install stanza ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Environment Variable Check for Stanza Resources Directory

import os
import stanza

# 1. Check if the Environment Variable is active in this terminal
env_path = os.getenv('STANZA_RESOURCES_DIR')

print("--- Environment Check ---")
if env_path:
    print(f"✅ Found STANZA_RESOURCES_DIR: {env_path}")
else:
    print("❌ STANZA_RESOURCES_DIR is NOT set or not visible to this Python process.")

# 2. Check where Stanza's default resource directory is pointing
from stanza.resources.common import DEFAULT_RESOURCES_URL
from stanza.pipeline.core import DownloadMethod

# This simulates the internal path resolution
try:
    # We check the default directory Stanza is using
    from stanza.utils.resources import get_default_resources_dir
    actual_dir = get_default_resources_dir()
    print(f"\n--- Stanza Logic Check ---")
    print(f"Stanza is currently targeting: {actual_dir}")
    
    if "D:\\" in actual_dir:
        print("🎉 Success! Stanza is pointing to your D: drive.")
    else:
        print("⚠️ Warning: Stanza is still pointing to the C: drive (User AppData).")
except Exception as e:
    print(f"Error checking directory: {e}")
# Out:
# --- Environment Check ---
# ✅ Found STANZA_RESOURCES_DIR: %DATASETS%\StanfordNLP\stanza
# Error checking directory: No module named 'stanza.utils.resources'

# %%
import stanza
stanza.download('en')
nlp_3 = stanza.Pipeline(lang='en', 
processors='tokenize,mwt,pos,lemma,depparse')
doc = nlp_3("The quick brown fox jumps over the lazy dog.")
for sentence in doc.sentences:
    for word in sentence.words:
        print(f'{word.text} → {word.head} ({word.deprel})')
# Out:
# ...
# 2026-03-15 13:59:24 INFO: Downloaded file to D:\DEV\datasets\StanfordNLP\stanza\resources.json
# 2026-03-15 13:59:24 INFO: Downloading default packages for language: en (English) ...
# ...
# 2026-03-15 14:02:18 INFO: Downloaded file to D:\DEV\datasets\StanfordNLP\stanza\en\default.zip
# 2026-03-15 14:02:21 INFO: Finished downloading models and saved to D:\DEV\datasets\StanfordNLP\stanza
# 2026-03-15 14:02:21 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2026-03-15 14:02:22 INFO: Downloaded file to D:\DEV\datasets\StanfordNLP\stanza\resources.json
# 2026-03-15 14:02:23 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# ...

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#       --------------------------------------- 0.8/42.8 MB 3.7 MB/s eta 0:00:12
#      - -------------------------------------- 1.6/42.8 MB 3.4 MB/s eta 0:00:13
#      - -------------------------------------- 2.1/42.8 MB 3.1 MB/s eta 0:00:14
#      -- ------------------------------------- 2.6/42.8 MB 3.0 MB/s eta 0:00:14
#      --- ------------------------------------ 3.4/42.8 MB 3.2 MB/s eta 0:00:13
#      --- ------------------------------------ 3.9/42.8 MB 3.4 MB/s eta 0:00:12
#      ---- ----------------------------------- 4.7/42.8 MB 3.2 MB/s eta 0:00:13
#      ---- ----------------------------------- 5.2/42.8 MB 3.1 MB/s eta 0:00:13
#      ----- ---------------------------------- 5.8/42.8 MB 3.1 MB/s eta 0:00:12
#      ----- ---------------------------------- 6.0/42.8 MB 2.9 MB/s eta 0:00:13
# ...

# %%
# Load the English model
nlp_4 = spacy.load("en_core_web_md")
# Text for NER
text = "Barack Obama was born in Hawaii and served as the president of the United States for the years (2009-2017)."
# Process the text
doc_2 = nlp_4(text)
# Display named entities
for ent in doc_2.ents:
    print(f"{ent.text:30} --> {ent.label_} ({spacy.explain(ent.label_)})")
# Out:
# Barack Obama                   --> PERSON (People, including fictional)
# Hawaii                         --> GPE (Countries, cities, states)
# the United States              --> GPE (Countries, cities, states)
# the years                      --> DATE (Absolute or relative dates or periods)
# 2009-2017                      --> DATE (Absolute or relative dates or periods)

# %%
doc_3 = nlp_4("West Bengal's Trinamool Congress leader Mahua Moitra has moved to the Supreme Court of India against her expulsion from the Lok Sabha as a Member of Parliament of India")
html = displacy.render(doc_3, style="ent", jupyter=False)
# 2. Wrap and display
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     West Bengal's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trinamool Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  leader
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahua Moitra
# ...

# %%
# Sample text
doc_4 = nlp("New York is a great city.")
# Merge "New York" into one token
with doc_4.retokenize() as retokenizer:
    span = doc_4[0:2] # Tokens "New" and "York"
retokenizer.merge(span)
# Print tokens after merging
print("After merging:")
for token in doc_4:
    print(token.text)
# Out:
# After merging:
# New
# York
# is
# a
# great
# city
# .

# %%
from spacy.tokens import Doc
# Let's say we want to split "don't" into "do" and "n't"
words = ["I", "do", "n't", "like", "apples"]
spaces = [True, False, True, True, False] # True = space follows the token
# Create a new Doc from words
new_doc = Doc(nlp.vocab, words=words, spaces=spaces)
print("After splitting:")
for token in new_doc:
    print(token.text)
# Out:
# After splitting:
# I
# do
# n't
# like
# apples

# %%
text = "Barack Obama visited New York last week."
doc_5 = nlp(text)
with doc_5.retokenize() as retokenizer:
    for ent in doc_5.ents:
        retokenizer.merge(ent)
    print("After merging named entities:")
    for token in doc_5:
        print(token.text, "->", token.ent_type_)
# Out:
# After merging named entities:
# Barack -> PERSON
# Obama -> PERSON
# visited ->
# New -> GPE
# York -> GPE
# last -> DATE
# week -> DATE
# . ->

# %% [markdown]
# # Week 5

# %%
#Week 5
text = 'Tesla opened a new Gigafactory in Berlin on March 22, 2022.'
doc_6 = nlp(text)
for ent in doc_6.ents:
    print(f"{ent.text} → {ent.label_} ({spacy.explain(ent.label_)})")
# Out:
# Tesla → ORG (Companies, agencies, institutions, etc.)
# Gigafactory → FAC (Buildings, airports, highways, bridges, etc.)
# Berlin → GPE (Countries, cities, states)
# March 22, 2022 → DATE (Absolute or relative dates or periods)

# %%
doc_7 = nlp('I want to fly from Mumbai to Delhi.')
for token in doc_7:
    if token.dep_ == 'ROOT': intent = token.text
    if token.dep_ == 'pobj' and token.head.text == 'from': departure = token.text
    if token.dep_ == 'pobj' and token.head.text == 'to': destination = token.text
print("Intent: "+intent, "Departure: "+departure, "Destination: "+destination)
# Out:
# Intent: want Departure: Mumbai Destination: Delhi

# %%
# Install the latest scispaCy (compatible with spaCy 3.8+)
# !pip install scispacy

# Install the latest models
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz (119.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz (119.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz (14.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy validate
# Out:
# ⠙ Loading compatibility table...
# ⠹ Loading compatibility table...
# ⠸ Loading compatibility table...
# ⠼ Loading compatibility table...
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.7.5) =================
# ℹ spaCy installation:
# d:\DEV\python-envs\ai-env\Lib\site-packages\spacy
#
# NAME               SPACY            VERSION
# en_core_sci_md     >=3.7.4,<3.8.0   0.5.4   ✔
# en_core_sci_sm     >=3.7.4,<3.8.0   0.5.4   ✔
# en_core_web_md     >=3.7.2,<3.8.0   3.7.1   ✔
# en_core_web_sm     >=3.7.2,<3.8.0   3.7.1   ✔
# en_ner_bc5cdr_md   >=3.7.4,<3.8.0   0.5.4   ✔

# %%
#Case Study -1 healthcare
import spacy
nlp_medical = spacy.load("en_core_sci_sm")
text = 'The patient was diagnosed with diabetes and prescribed Metformin on March 12 2023...'
doc_cs_1 = nlp(text)
for ent in doc_cs_1.ents:
    print(ent.text, ent.label_)
# Out:
# d:\DEV\python-envs\ai-env\Lib\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# Metformin PERSON
# March 12 2023 DATE

# %%
#Case Study -2 law
text = 'The High Court of Bombay cited the Companies Act, 2013 on August 5 2022.'
doc_cs_2 = nlp(text)
for ent in doc_cs_2.ents:
    print(ent.text, ent.label_)
# Out:
# The High Court ORG
# Bombay GPE
# the Companies Act LAW
# 2013 DATE
# August 5 2022 DATE

# %%
#Case Study -3 Finance
text = 'Infosys reported a revenue of ₹23,000 crores in Q2 FY23.'
doc_cs_3 = nlp(text)
for ent in doc_cs_3.ents:
    print(ent.text, ent.label_)
# Out:
# Infosys ORG
# 23,000 MONEY
# Q2 CARDINAL

# %%
#Case Study -4 News
text = 'Joe Biden met with NATO leaders in Brussels on March 25.'
doc_cs_4 = nlp(text)
for ent in doc_cs_4.ents:
    print(ent.text, ent.label_)
# Out:
# Joe Biden PERSON
# NATO ORG
# Brussels GPE
# March 25 DATE

# %%
#Case Study -5 ECommerce
text = 'I loved the brand new Apple iPhone 13 Pro Max I bought last week!'
doc_cs_5 = nlp(text)
for ent in doc_cs_5.ents:
    print(ent.text, ent.label_)
# Out:
# Apple ORG
# 13 CARDINAL
# last week DATE

# %%
#Case Study -6 Education
text = 'Completed B.Tech in Computer Science from NIT Trichy with the Python and ML certificate...'
doc_cs_6 = nlp_4(text)
for ent in doc_cs_6.ents:
    print(ent.text, ent.label_)
# Out:
# Completed B.Tech in Computer Science ORG
# NIT Trichy ORG
# Python ORG

# %%
#Case Study -7 Ciatation project
text = 'As per [Smith et al., 2021] in Nature, quantum AI has vast potential.'
doc_cs_7 = nlp(text)
for ent in doc_cs_7.ents:
    print(ent.text, ent.label_)
# Out:
# Smith GPE
# al. GPE
# 2021 CARDINAL
# Nature GPE
# AI ORG

# %%
#Case Study -8 Hotel Booking
text = 'Book a 3-night stay at Hotel Marriott in Dubai from June 12 to June 15.'
doc_cs_8 = nlp(text)
for ent in doc_cs_8.ents:
    print(ent.text, ent.label_)
# Out:
# 3-night TIME
# Hotel Marriott ORG
# Dubai GPE
# June 12 to June 15 DATE

# %%
#Chatbot
text = 'Can you book me a train ticket to Pune?'
doc_cb_1 = nlp(text)
for token in doc_cb_1:
    if token.dep_ == 'pobj' and token.head.text == 'to':
        print('Destination:', token.text)
# Out:
# Destination: Pune

# %%
#Case Study -9 Student Question
text = 'How does photosynthesis occur in plants?'
doc_cs_9 = nlp(text)
for token in doc_cs_9:
    print(token.text, token.dep_, token.head.text)
# Out:
# How advmod occur
# does aux occur
# photosynthesis nsubj occur
# occur ROOT occur
# in prep occur
# plants pobj in
# ? punct occur

# %%
#Case Study -10 Customer Support
text = 'The display of my Dell laptop is flickering.'
doc_cs_10 = nlp(text)
for token in doc_cs_10:
    print(token.text, token.dep_, token.head.text)
# Out:
# The det display
# display nsubj flickering
# of prep display
# my poss laptop
# Dell compound laptop
# laptop pobj of
# is aux flickering
# flickering ROOT flickering
# . punct flickering

# %%
#Travel Booking
text = 'I need a cab from Bangalore to Mysore.'
doc_cb_2 = nlp(text)
for token in doc_cb_2:
    if token.dep_ == 'pobj' and token.head.text in ['from', 'to']:
        print(token.head.text.capitalize(), '→', token.text)
# Out:
# From → Bangalore
# To → Mysore

# %%
pip install pandas nltk gensim textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
exit
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import nltk

print("--- NLTK Installation & Path Check ---")

# 1. Check Library Version
print(f"NLTK Version: {nltk.__version__}")

# 2. Check the NLTK_DATA Environment Variable
env_path = os.environ.get('NLTK_DATA')
print(f"NLTK_DATA Variable: {env_path if env_path else '❌ NOT SET'}")

# 3. Check where NLTK is actually looking
print("\n--- Search Paths (Priority Order) ---")
for path in nltk.data.path:
    status = "✅ Found" if os.path.exists(path) else "❓ Path does not exist"
    print(f"- {path} ({status})")

# 4. Functional Test: Try to load 'punkt'
print("\n--- Functional Test ---")
try:
    nltk.data.find('tokenizers/punkt')
    print("✅ Resource 'punkt' found and accessible.")
except LookupError:
    print("❌ Resource 'punkt' NOT found.")
    print("   Attempting a redirect download to D: drive...")
    # This will use your env variable if set, otherwise it defaults to the first valid path
    nltk.download('punkt')
# Out:
# --- NLTK Installation & Path Check ---
# NLTK Version: 3.9.3
# NLTK_DATA Variable: %DATASETS%\nltk_data
#
# --- Search Paths (Priority Order) ---
# - %DATASETS%\nltk_data (❓ Path does not exist)
# - C:\Users\Aravind Subramanian/nltk_data (❓ Path does not exist)
# - d:\DEV\python-envs\ai-env\nltk_data (❓ Path does not exist)
# - d:\DEV\python-envs\ai-env\share\nltk_data (❓ Path does not exist)
# - d:\DEV\python-envs\ai-env\lib\nltk_data (❓ Path does not exist)
# - C:\Users\Aravind Subramanian\AppData\Roaming\nltk_data (✅ Found)
# - C:\nltk_data (❓ Path does not exist)
# - D:\nltk_data (❓ Path does not exist)
# - E:\nltk_data (❓ Path does not exist)
#
# --- Functional Test ---
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[2], line 22
#      20 print("\n--- Functional Test ---")
#      21 try:
# ---> 22     nltk.data.find('tokenizers/punkt')
# ...

# %%
#Text preprocessing

import pandas as pd
import nltk, spacy, gensim
from textblob import TextBlob, Word
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import warnings

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Aravind
# [nltk_data]     Subramanian\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       7 from nltk.stem import WordNetLemmatizer
#       8 import warnings
# ---> 10 nltk.download('punkt')
#      11 nltk.download('averaged_perceptron_tagger')
#      12 nltk.download('maxent_ne_chunker')
#
# File d:\DEV\python-envs\ai-env\Lib\site-packages\nltk\downloader.py:762, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     753 def show(s, prefix2=""):
#     754     print_to(
#     755         textwrap.fill(
#     756             s,
#    (...)    759         )
#     760     )
# --> 762 for msg in self.incr_download(info_or_id, download_dir, force):
#     763     # Error messages
# ...

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Aravind
# [nltk_data]     Subramanian\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = '''
Nuslias are used for the production of high fructose syrup and 
pharma industries.
Aspergillus in shake flask fermentation.
First report on properties of Anega 442.
'''

# %%
import re
text = text.lower()
text = re.sub(r'\W+',' ', text)
text = re.sub(r'\d+', '', text)

# %%
text
# Out:
# ' nuslias are used for the production of high fructose syrup and pharma industries aspergillus in shake flask fermentation first report on properties of anega  '

# %%
from collections import Counter
def remove_rare_words(text, threshold=2):
    words = nltk.word_tokenize(text)
    freq = Counter(words)
    filtered = [w for w in words if freq[w] >= threshold]
    return ' '.join(filtered)
text = remove_rare_words(text)

# %%
text
# Out:
# 'of of'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Aravind
# [nltk_data]     Subramanian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text)
filtered_tokens = [t for t in tokens if t not in stop_words]

# %%
text
# Out:
# 'of of'

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in 
filtered_tokens]

# %%
stemmed_tokens
# Out:
# []

# %%
sentence = ' '.join(filtered_tokens)
doc = nlp_4(sentence)
lemmatized_tokens = [token.lemma_ for token in doc]

# %%
lemmatized_tokens
# Out:
# []

# %% [markdown]
# # Week 6

# %%
#Case Study 11 - Airlines

import pandas as pd
import spacy
from collections import Counter
# Load spaCy model
nlp_4 = spacy.load("en_core_web_md")
# Sample airline reviews (replace with actual dataset
reviews = [
    "I flew from Toronto to New York on Air Canada.",
    "Delta Airlines provided great service.",
    "Lufthansa was ayed at Frankfurt airport."
]
# Extract entities
entity_counter = Counter()
for review in reviews:
    doc_cs_11 = nlp_4(review)
    for ent in doc_cs_11.ents:
        entity_counter [ent.text] += 1
# Display top 10 entities
print("Top 10 Entities:")
for entity, freq in entity_counter.most_common (10):
    print (f"{entity}: {freq}")
# Out:
# Top 10 Entities:
# Toronto: 1
# New York: 1
# Air Canada: 1
# Delta Airlines: 1
# Lufthansa: 1
# Frankfurt: 1

# %%
#Case Study 12 - Headlines

headlines = [
"WHO declares global emergency due to outbreak in Wuhan.",
"Biden meets with NATO leaders in Brussels.",
"Apple announces new iPhone at Cupertino HQ."
]

for title in headlines:
    doc_cs_12 = nlp_4(title)
    print(f"\n{title}")
    for ent in doc_cs_12.ents:
        print(f" - {ent.text} ({ent.label_})")
# Out:
# WHO declares global emergency due to outbreak in Wuhan.
#  - WHO (ORG)
#  - Wuhan (GPE)
#
# Biden meets with NATO leaders in Brussels.
#  - Biden (PERSON)
#  - NATO (ORG)
#  - Brussels (GPE)
#
# Apple announces new iPhone at Cupertino HQ.
#  - Apple (ORG)
#  - iPhone (ORG)
#  - Cupertino HQ (ORG)

# %%
#Case Study 13 - Resumes

resumes = [
"John has a Master's in Computer Science from Stanford University and works at Google in California.",
"Priya completed her B.Tech at IIT Delhi and interned at Microsoft."
]
for resume in resumes:
    doc_cs_13 = nlp_4(resume)
    print(f"\nResume: {resume}")
    for ent in doc_cs_13.ents:
        print(f" - {ent.text} ({ent.label_})")
# Out:
# Resume: John has a Master's in Computer Science from Stanford University and works at Google in California.
#  - John (PERSON)
#  - Computer Science (ORG)
#  - Stanford University (ORG)
#  - Google (ORG)
#  - California (GPE)
#
# Resume: Priya completed her B.Tech at IIT Delhi and interned at Microsoft.
#  - IIT Delhi (GPE)
#  - Microsoft (ORG)

# %%
#Case Study 14 - Resumes

resumes = [
"John has a Master's in Computer Science from Stanford University and works at Google in California.",
"Priya completed her B.Tech at IIT Delhi and interned at Microsoft."
]
for resume in resumes:
    doc_cs_14 = nlp_4(resume)
    print(f"\nResume: {resume}")
    for ent in doc_cs_14.ents:
        print(f" - {ent.text} ({ent.label_})")
# Out:
# Resume: John has a Master's in Computer Science from Stanford University and works at Google in California.
#  - John (PERSON)
#  - Computer Science (ORG)
#  - Stanford University (ORG)
#  - Google (ORG)
#  - California (GPE)
#
# Resume: Priya completed her B.Tech at IIT Delhi and interned at Microsoft.
#  - IIT Delhi (GPE)
#  - Microsoft (ORG)

# %%
#Case Study 15 - Legal

legal_text = "Case No. 12345 was filed in the Supreme Court of India on 5th May 2023."
doc_cs_15 = nlp_4(legal_text)
for ent in doc_cs_15.ents:
    print(f" - {ent.text} ({ent.label_})")
# Out:
#  - 12345 (CARDINAL)
#  - the Supreme Court of India (ORG)
#  - 5th May 2023 (DATE)

# %%
#Case Study 16 - Disaster

tweets = [
"Earthquake reported in San Francisco #earthquake",
"Protesters gather in New Delhi near Parliament #protest"
]
for tweet in tweets:
    doc_cs_16 = nlp_4(tweet)
    print(f"\nTweet: {tweet}")
    for ent in doc_cs_16.ents:
        print(f"{ent.text} ({ent.label_})")
# Out:
# Tweet: Earthquake reported in San Francisco #earthquake
# San Francisco # (LOC)
#
# Tweet: Protesters gather in New Delhi near Parliament #protest
# New Delhi (GPE)

# %%
#Case Study 17 - Medical

medical_notes = [
    "Patient was prescribed Metformin for type 2 diabetes.",
    "Symptoms include high fever, sore throat, and body aches."
]

for note in medical_notes:
    doc_cs_17 = nlp_medical(note)
    print(f"\nMedical Note: {note}")
    for ent in doc_cs_17.ents:
        print(f" {ent.text} ({ent.label_})")
# Out:
# Medical Note: Patient was prescribed Metformin for type 2 diabetes.
#  Patient (ENTITY)
#  prescribed (ENTITY)
#  Metformin (ENTITY)
#  type 2 diabetes (ENTITY)
#
# Medical Note: Symptoms include high fever, sore throat, and body aches.
#  Symptoms (ENTITY)
#  high fever (ENTITY)
#  sore throat (ENTITY)
#  body aches (ENTITY)

# %% [markdown]
# # Week 12

# %%
pip install transformers fastapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis", model="xlm-roberta-base")
print(classifier("C'est une belle journée!"))
# Out:
# ...
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification LOAD REPORT from: xlm-roberta-base
# Key                         | Status     |
# ----------------------------+------------+-
# roberta.pooler.dense.bias   | UNEXPECTED |
# lm_head.dense.bias          | UNEXPECTED |
# lm_head.layer_norm.bias     | UNEXPECTED |
# lm_head.bias                | UNEXPECTED |
# roberta.pooler.dense.weight | UNEXPECTED |
# lm_head.dense.weight        | UNEXPECTED |
# lm_head.layer_norm.weight   | UNEXPECTED |
# classifier.out_proj.weight  | MISSING    |
# classifier.out_proj.bias    | MISSING    |
# classifier.dense.weight     | MISSING    |
# classifier.dense.bias       | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ...

# %%
from fastapi import FastAPI
from transformers import pipeline

app = FastAPI()

# Explicitly specify the model
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english",
    revision="714eb0f"  # optional, locks to a specific version
)

@app.get("/predict")
def predict(text: str):
    result = classifier(text)
    return {"result": result}
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
predict("Au Revoir!")
# Out:
# {'result': [{'label': 'POSITIVE', 'score': 0.9990665316581726}]}
